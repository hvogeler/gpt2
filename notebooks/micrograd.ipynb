# %%
from gpt2.micrograd.micrograd import Value

a = Value(4.0)
b = Value(5.0)
c = Value(6.0)

d = a * b + c
print(f"d.prev = {d.prev}, {d.op}")
# Out:
# d.prev = {Value(data=20.0), Value(data=6.0)}, +

# %%
for v in d.prev:
    print(f"v = {v.prev} - op = {v.op}")
# Out:
# v = {Value(data=5.0), Value(data=4.0)} - op = *
# v = set() - op =

# %%
from gpt2.micrograd.micrograd import draw_dot

draw_dot(d)
